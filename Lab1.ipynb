# %% [markdown]
# ## Lab 1 Data Collection, Preprocessing, and Visualization in R
# #### Data Science UAB Summer Camp 2026

# %% [markdown]
# ### <div class="alert alert-block alert-success"> Section 1: R Warm-Up and Data Structures </div>

# %% [markdown]
# In this lab, we will begin working with real data in R.
#
# You have already received **Lab 0: Introduction to R** as a preparation tutorial. This section is a short review of the most important ideas we need before working with datasets.
#
# By the end of this lab, you should be able to:
#
# - Load and inspect a dataset in R
# - Understand basic R data structures
# - Use vectors, matrices, data frames, and data tables
# - Clean and preprocess data
# - Create simple but meaningful visualizations
# - Communicate one clear data insight

# %% [markdown]
# Check R version

# %%
R.version.string

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 1.1 R as a Calculator </div>
#    - Addition (`+`)
#    - Subtraction (`-`)
#    - Multiplication (`*`)
#    - Division (`/`)
#    - Exponentiation (`^`)
#    - Modulus (`%%`)
#    - Integer Division (`%/%`)
#
#    *Example:*

# %%
   5 + 3   # Addition
   10 - 4  # Subtraction
   7 * 2   # Multiplication
   21 / 5  # Division
   2^3     # Exponentiation
   10 %% 3 # Modulus
   10 %/% 3 # Integer Division

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 1.2 Creating Objects </div>
# In R, we can store values using an object name.
#
# The assignment operator `<-` means "save the value on the right into the object on the left."

# %%
x <- 10
x

# %%
y <- 5
x + y

# %% [markdown]
# You may also see `=` used for assignment. In this camp, we will mostly use `<-`, which is very common in R.

# %% [markdown]
# #### <div class="alert alert-block alert-warning"> 1.3: R for Python Users </div>
#
# Many of you may have used Python before. Here are a few important differences.
#
# | Concept | Python | R |
# |---|---|---|
# | Assignment | `x = 10` | `x <- 10` |
# | Indexing starts at | 0 | 1 |
# | List-like vector | `[1, 2, 3]` | `c(1, 2, 3)` |
# | Data table | `pandas.DataFrame` | `data.frame`, `tibble`, or `data.table` |
# | Missing value | `None` or `NaN` | `NA` |
#
# The most important difference for today is that **R indexing starts at 1**.

# %%
x <- c(1, 2, 3, 4, 5)
mean(x)
x[1]

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 1.4 Vectors </div>
# A vector is one of the most basic data structures in R.
#
# A vector stores multiple values of the same general type.

# %%
# Creating a vector
vec <- c(1, 2, 3, 4, 5)
vec

# %%
# Accessing elements
vec[1]    # First element
vec[1:3]  # First three elements

# %%
# Vector operations
vec + 2       # Adds 2 to each element
vec * 2       # Multiplies each element by 2
sum(vec)      # Sum of elements
mean(vec)     # Mean of elements

# %% [markdown]
# try `median`, `max`, `min`.

# %% [markdown]
# Vectors can also contain character values.

# %%
schools <- c("Hoover", "Vestavia", "Homewood", "Helena")
schools

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 1.5 Logical Comparisons </div>
#
# Logical comparisons return `TRUE` or `FALSE`.
#
# These are very useful when filtering data.

# %%
scores <- c(85, 90, 78, 92, 88)
scores

# %%
scores > 85

# %%
scores[scores > 85]

# %% [markdown]
# The expression above means:
#
# > Keep only the scores greater than 85.

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 1.6 Matrices </div>
# A matrix is a rectangular table of numbers.
#
# Matrices are important in data science because many machine learning methods are built on matrix operations.

# %%
A <- matrix(
  c(1, 2, 3, 4, 5, 6),
  nrow = 2,
  ncol = 3
)

A

# %%
dim(A)

# %%
A[1, 2]

# %% [markdown]
# In matrix indexing:
#
# - The first index is the row.
# - The second index is the column.
#
# So `A[1, 2]` means row 1, column 2.

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 1.7 Data Frames </div>
#
# A data frame is one of the most important data structures in R.
#
# A data frame is like a spreadsheet:
#
# - Each row is an observation.
# - Each column is a variable.
#
# For example, suppose we have data from several cars.

# %%
cars_small <- data.frame(
  car = c("Car A", "Car B", "Car C", "Car D"),
  weight = c(2200, 2800, 3200, 3600),
  mpg = c(32, 27, 23, 19)
)

cars_small

# %% [markdown]
# Here:
#
# - Each row represents one car.
# - `weight` is the vehicle weight in pounds.
# - `mpg` is fuel efficiency, measured in miles per gallon.

# %%
str(cars_small)

# %%
summary(cars_small)

# %%
cars_small$weight

# %%
cars_small$mpg

# %% [markdown]
# The `$` symbol selects one column from a data frame.

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 1.8 Tibbles </div>
# A tibble is a modern version of a data frame used by the `tidyverse`.
#
# Tibbles print nicely and are convenient for data analysis.

# %%
# Install if needed:
# install.packages("tidyverse")

library(tidyverse)

# %%
cars_tibble <- as_tibble(cars_small)

cars_tibble

# %% [markdown]
# For most beginner-level work, you can think of a tibble as a friendly version of a data frame.

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 1.9 Data Tables </div>
# A `data.table` is another data structure for working with data in R.
#
# It is especially useful for large datasets because it is fast and memory-efficient.

# %%
# Install if needed:
# install.packages("data.table")

library(data.table)

# %%
cars_dt <- as.data.table(cars_small)

cars_dt

# %% [markdown]
# Basic `data.table` syntax has the form:
#
# ```r
# DT[i, j, by]
# ```
#
# where:
# - `i` selects rows
# - `j` selects columns or calculations
# - `by` groups data

# %%
# Select cars with weight greater than 2800
cars_dt[weight > 2800]

# %%
# Compute average MPG
cars_dt[, mean(mpg)]

# %%
# Select only weight and mpg columns
cars_dt[, .(weight, mpg)]

# %% [markdown]
# In this camp, we will use both `tidyverse` and `data.table`.
#
# - `tidyverse` is readable and widely used for teaching.
# - `data.table` is fast and powerful for larger datasets.
#
# You do not need to master both today. The goal is to become comfortable reading and running basic commands.

# %% [markdown]
# #### <div class="alert alert-block alert-info"> 1.10 Quick Practice </div>
#
# Try answering the following questions using the small car dataset.
#
# 1. What is the average car weight?
# 2. What is the average MPG?
# 3. Which cars have MPG greater than 25?
# 4. Which cars weigh more than 3000 pounds?

# %%
# 1. Average car weight

# %%
# 2. Average MPG

# %%
# 3. Cars with MPG greater than 25

# %%
# 4. Cars weighing more than 3000 pounds

# %% [markdown]
# ### <div class="alert alert-block alert-success"> Section 2: Data Collection and Importing Data </div>
#
# Before we can analyze data, we first need to obtain it.
#
# Data scientists collect data from many different sources, including:
#
# - Surveys
# - Scientific experiments
# - Sensors and smart devices
# - Government databases
# - Websites and APIs
# - Business records
#
# Today, we will work with a real dataset about automobiles.
#
# The dataset contains information about vehicles, including:
#
# - Fuel efficiency (MPG)
# - Number of cylinders
# - Horsepower
# - Weight
# - Model year
#
# Later in this camp, we will use this dataset to build machine learning models.

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 2.1 Loading Packages </div>
#
# Packages extend the functionality of R.
#
# Today we will use:
#
# - `data.table` for data manipulation
# - `tidyverse` for data analysis and visualization

# %%
library(data.table)
library(tidyverse)

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 2.2 Importing a CSV File </div>
#
# CSV stands for:
#
# **Comma-Separated Values**
#
# CSV files are one of the most common formats used to store data.
#
# Our automobile dataset is stored in:
#
# ```text
# data/auto_mpg_raw.csv
# ```
#
# The `fread()` function from `data.table` reads a CSV file into R.

# %%
auto <- fread("https://raw.githubusercontent.com/kerenli/Data-Science-UAB-Summer-Camp/main/data/auto_mpg.csv")

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 2.3 First Look at the Dataset </div>
#
# Whenever you receive a new dataset, the first step is to understand its structure.
#
# Useful questions include:
#
# - How many observations are there?
# - How many variables are there?
# - What are the variable names?
# - What data types are present?

# %%
head(auto)

# %%
tail(auto)

# %%
dim(auto)

# %%
nrow(auto)

# %%
ncol(auto)

# %%
names(auto)

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 2.4 Understanding Variables </div>
#
# The `str()` function displays the structure of a dataset.*

# %%
str(auto)

# %% [markdown]
# Notice that different variables have different types.
#
# For example:
#
# - Numeric variables:
#     - mpg
#     - horsepower
#     - weight
#
# - Character variables:
#     - name
#
# Understanding variable types is an important first step in data preprocessing.

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 2.5 Summary Statistics </div>
#
# The `summary()` function provides a quick overview of each variable.

# %%
summary(auto)

# %% [markdown]
# Questions:
#
# 1. What is the average MPG?
# 2. What is the lightest vehicle?
# 3. What is the heaviest vehicle?
# 4. Which year appears most frequently?

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 2.6 Looking at Individual Variables </div>
#
# We can access a single column using `$`.

# %%
head(auto$mpg)

# %%
head(auto$weight)

# %%
head(auto$name)

# %% [markdown]
# We can also compute summaries manually.

# %%
mean(auto$mpg, na.rm = TRUE)

# %%
median(auto$mpg, na.rm = TRUE)

# %%
sd(auto$mpg, na.rm = TRUE)

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 2.7 Data Collection in Practice </div>
#
# In this lab, the dataset has already been prepared for you.
#
# In real projects, data scientists often download data directly from websites.
#
# For example, a CSV file can sometimes be loaded directly from a URL.

# %%
url <- paste0(
  "https://mesonet.agron.iastate.edu/cgi-bin/request/asos.py?",
  "station=BHM&",
  "data=tmpf&",
  "year1=1950&month1=1&day1=1&",
  "year2=2025&month2=12&day2=31&",
  "tz=Etc/UTC&format=onlycomma&latlon=no&elev=no&missing=M&trace=T&direct=no&report_type=1&report_type=2"
)

weather <- fread(url)

# %% [markdown]
# Many modern datasets come from APIs.
#
# Examples include:
#
# - Weather data
# - Stock prices
# - Sports statistics
# - Social media data
#
# During this camp, we will mainly work with prepared datasets so that we can focus on analysis and machine learning.

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 2.8 Quick Exploration Challenge </div>
#
# Working with a partner, answer the following questions.
#
# 1. How many cars are in the dataset?
#
# 2. Which car has the highest MPG?
#
# 3. Which car has the lowest MPG?
#
# 4. What is the average vehicle weight?
#
# 5. What variables might be useful for predicting MPG?

# %%
# Number of cars
nrow(auto)

# %%
# Highest MPG
auto[which.max(mpg)]

# %%
# Lowest MPG
auto[which.min(mpg)]

# %%
# Average weight
mean(auto$weight)

# %% [markdown]
# ### <div class="alert alert-block alert-success"> Section 3: Data Preprocessing </div>
#
# Real-world datasets are rarely perfect.
#
# Common data issues include:
#
# - Missing values
# - Incorrect data types
# - Duplicate records
# - Inconsistent labels
# - Outliers
#
# Before analyzing data, we should inspect and clean the dataset.
#
# This process is called **data preprocessing**.

# %% [markdown]
# In this section, we will work with a sample of Chicago police traffic stop dataset.
#
# Our goal is to identify potential issues and prepare the data for analysis.
#
# What can we learn from police traffic stop records?

# %%
library(data.table)

stops <- fread(
  "https://raw.githubusercontent.com/kerenli/Data-Science-UAB-Summer-Camp/main/data/il_chicago_2023_01_26_small.csv"
)

head(stops)

# %%
dim(stops)

# %%
names(stops)

# %%
str(stops)

# %%
summary(stops)

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 3.1 Checking for Missing Values </div>
#
# Missing values are represented by `NA` in R.
#
# One of the first things a data scientist should do is determine whether any data are missing.

# %%
sum(is.na(stops))

# %%
colSums(is.na(stops))

# %% [markdown]
# Questions
#
# 1. Which variables contain missing values?
# 2. Why might information be missing?
# 3. Should we remove those observations or keep them?

# %%
missing_summary <- data.table(
  variable = names(stops),
  missing = colSums(is.na(stops))
)

missing_summary[, percent_missing :=round(100 * missing / nrow(stops), 2)]

missing_summary[order(-percent_missing)]

# %% [markdown]
# Should we trust a variable with 50% missing values?

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 3.2 Convert Variables </div>
# Many variables should be factors.

# %%
stops[ , subject_sex := factor(subject_sex)]

stops[ , subject_race := factor(subject_race)]

stops[ , violation := factor(violation)]

# %%
str(stops)

# %% [markdown]
# Categorical variables should be stored as factors.

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 3.3 Create New Variables </div>
# Age Difference

# %%
stops[ , age_difference := officer_age - subject_age]

# %%
summary(stops$age_difference)

# %% [markdown]
# Are officers generally older than drivers?

# %% [markdown]
# ### <div class="alert alert-block alert-success"> 3.4 Create Time of Day Category </div>
#
# This is an excellent feature engineering example.

# %%
stops[ , hour := as.integer(substr(time, 1, 2))]

# %%
stops[ , time_period := fifelse(hour < 6, "Night", 
         fifelse(hour < 12, "Morning", 
         fifelse(hour < 18, "Afternoon", "Evening")))]

# %%
?fifelse

# %%
stops

# %% [markdown]
# ### <div class="alert alert-block alert-success"> 3.5 Filtering </div>
# Example: How many stops involve drivers under 25?

# %%
young_drivers <- stops[subject_age < 25]

young_drivers

# %% [markdown]
# ### <div class="alert alert-block alert-success"> 3.6 Group Summaries </div>
# By Sex

# %%
stops[ , .N, by = subject_sex]

# %% [markdown]
# By Violation

# %%
stops[ , .N, by = violation][order(-N)]

# %% [markdown]
# ### <div class="alert alert-block alert-success"> 3.7 Create Analysis Dataset </div>

# %%
stops_clean <- stops[!is.na(subject_age)]

stops_clean

# %%
stops_clean <- stops_clean[, .(subject_age,
  subject_race,
  subject_sex,
  violation,
  arrest_made,
  citation_issued)]

# %%
fwrite(stops_clean, "data/stops_clean.csv")

# %% [markdown]
# ### <div class="alert alert-block alert-success"> Section 4: Data Visualization and Communication </div>
#
# A picture is often easier to understand than a table of numbers.
#
# Data visualization helps us:
#
# - Discover patterns
# - Identify unusual observations
# - Compare groups
# - Communicate findings
#
# In this section, we will use `ggplot2`, one of the most popular visualization libraries in R.

# %%
library(ggplot2)

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 4.1 The Grammar of Graphics </div>
#
# Most ggplot figures follow the same structure:
#
# ```r
# ggplot(data, aes(...)) +
#     geom_...
# ```
#
# Think of this as:
#
# 1. Choose a dataset
# 2. Choose variables
# 3. Choose a type of plot

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 4.2 Distribution of Driver Age </div>
#
# A histogram shows how numerical values are distributed.
#
# Question:
#
# How old are the drivers in our dataset?

# %%
ggplot(stops_clean, aes(subject_age)) +
  geom_histogram(bins = 20) +
  labs(
    title = "Distribution of Driver Age",
    x = "Age",
    y = "Count"
  ) +
  theme_minimal()

# %% [markdown]
# Discussion
#
# - What age range appears most common?
# - Are very young drivers common?
# - Are very old drivers common?

# %% [markdown]
# #### <div class="alert alert-block alert-success"> 4.3 Most Common Violations </div>
#
# Bar charts are useful for categorical variables.
#
# Question:
#
# Which violations occur most often?

# %%
top_violation <- stops_clean[ , .N, by = violation][order(-N)][1:10]

ggplot(top_violation,  aes(x = reorder(violation, N), y = N)) +
  geom_col() +
  coord_flip() +
  labs(
    title = "Top 10 Most Common Violations",
    x = "Violation",
    y = "Number of Stops"
  ) +
  theme_minimal()

# %%
top_violation[ , violation_short := substr(violation, 1, 10)]

ggplot(top_violation, aes(x = reorder(violation_short, N), y = N)) +
  geom_col() +
  coord_flip() +
  labs(
    title = "Top 10 Most Common Violations",
    x = "Violation",
    y = "Number of Stops"
  ) +
  theme_minimal()

# %% [markdown]
# What proportion of all stops come from the top 10 violations?

# %%
top10_count <- top_violation[ , sum(N)]

total_count <- nrow(stops_clean)

100 * top10_count / total_count

# %% [markdown]
# ### <div class="alert alert-block alert-success"> Section 5: Mini Practice </div>
#
# Congratulations!
#
# You have now completed the major steps of a basic data science workflow:
#
# 1. Collect data
# 2. Explore data
# 3. Clean data
# 4. Visualize data
#
# Now it is your turn to investigate the dataset and communicate a finding.

# %% [markdown]
# #### <div class="alert alert-block alert-info"> The Data Science Workflow </div>
#
# Throughout this camp, we will repeatedly use the following process:
#
# Question
#
# ↓
#
# Data
#
# ↓
#
# Analysis
#
# ↓
#
# Visualization
#
# ↓
#
# Communication
#
# The goal is not just to create plots.
#
# The goal is to answer questions using data.

# %% [markdown]
# #### <div class="alert alert-block alert-info"> Project Goal </div>
#
# Work with a partner.
#
# Choose one question about the traffic stop dataset.
#
# Use R to explore the data.
#
# Create one visualization.
#
# Write a short conclusion.

# %% [markdown]
# #### <div class="alert alert-block alert-info"> Example Questions </div>
#
# You may use one of these questions or create your own.
#
# ##### Driver Characteristics
#
# - What ages are most commonly involved in traffic stops?
# - Are most stopped drivers male or female?
# - How does driver age vary by sex?
#
# ##### Traffic Violations
#
# - What are the most common violations?
# - Do different districts have different patterns of violations?
#
# ##### Officer Characteristics
#
# - What is the distribution of officer age?
# - How many years of service do officers typically have?
#
# ##### Time Patterns
#
# - Do more stops occur during the day or at night?
# - Are certain violations more common at specific times?
#
# ##### Geography
#
# - Which locations have the most traffic stops?
# - Which districts appear most active?

# %% [markdown]
# ##### <div class="alert alert-block alert-info"> Step 1: Formulate a Question </div>
#
# Write your question below.
#
# Example:
#
# "Do younger drivers account for most traffic stops?"

# %% [markdown]
# ##### <div class="alert alert-block alert-info"> Step 2: Explore the Data </div>
#
# Use commands such as:
#
# - head()
# - summary()
# - table()
# - group summaries
#
# to understand the variables related to your question.

# %% [markdown]
# ##### <div class="alert alert-block alert-info"> Step 3: Create a Visualization </div>
#
# Choose an appropriate plot:
#
# - Histogram
# - Bar chart
# - Boxplot
# - Scatterplot
#
# Remember:
#
# A good plot should have
#
# - A title
# - Axis labels
# - Readable text

# %% [markdown]
# ##### <div class="alert alert-block alert-info"> Step 4: Interpret Your Results </div>
#
# Describe what you observe.
#
# Observation:
#
# ____________________________________________________
#
# Evidence:
#
# ____________________________________________________
#
# Interpretation:
#
# ____________________________________________________

# %% [markdown]
# ### Communicating Results
#
# A good data scientist does more than generate plots.
#
# A good data scientist can explain:
#
# - What question was asked?
# - What evidence was found?
# - What conclusion can be supported?
#
# Remember:
#
# Data alone are not enough.
#
# Insights come from interpreting the data.
